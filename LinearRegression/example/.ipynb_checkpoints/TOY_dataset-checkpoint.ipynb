# %% [markdown]
# # TOY DATASET

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from LinearRegression import LinearRegression

# %%
x1 = np.linspace(10,30,50)
x2 = np.linspace(10,30,50)
noise = np.random.random(50)*20
y = (2*x1 + 5*x2 + noise).reshape(-1,1)
X = pd.DataFrame(data={'x1':x1,'x2':x2})

# %% [markdown]
# ### LinearRegression CLASSIC

# %%
model = LinearRegression(lr=1e-3, eps=1e-5)
model.fit(X, y)
y_pred = model.predict(X)
print(f'R-squared without normalisation: {model.score(y, y_pred):.4f}')
model.plot_actualVSpredicted(y, y_pred)
# model.plot()
# Out:
# --- Itération 0 ---
# MSE = 6.7017921E+03
#
# Fit process ended with success
# MSE = 13.612088165512489
#
# R-squared without normalisation: 0.9856

# %% [markdown]
# ### LinearRegression + NORMALISATION

# %%
model = LinearRegression(lr=1e-3, eps=1e-5)
model.fit(X, y, standardize=True)
y_pred = model.predict(X)
print(f'R-squared after Normalisation: {model.score(y, y_pred):.4f}')
model.plot_actualVSpredicted(y, y_pred)
# model.plot()
# Out:
# --- Itération 0 ---
# MSE = 1.2092114E+04
#
# --- Itération 1000 ---
# MSE = 1.5402468E+03
#
# --- Itération 2000 ---
# MSE = 2.1791430E+02
#
# --- Itération 3000 ---
# MSE = 4.1037361E+01
#
# --- Itération 4000 ---
# MSE = 1.7158315E+01
#
# --- Itération 5000 ---
# MSE = 1.3930502E+01
#
# --- Itération 6000 ---
# MSE = 1.3494114E+01
#
# Fit process ended with success
# MSE = 13.493164935403222
#
# R-squared after Normalisation: -416.5666

# %% [markdown]
# ### LinearRegression + REGULARISATION

# %%
model = LinearRegression(lr=1e-3, eps=1e-5)
model.fit(X, y, standardize=True, regularization='ELASTIC')
y_pred = model.predict(X)
print(f'R-squared after Regularisation: {model.score(y, y_pred):.4f}')
model.plot_actualVSpredicted(y, y_pred)
# model.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 model = LinearRegression(lr=1e-3, eps=1e-5)
# ----> 2 model.fit(X, y, standardize=True, regularization='ELASTIC')
#       3 y_pred = model.predict(X)
#       4 print(f'R-squared after Regularisation: {model.score(y, y_pred):.4f}')
#
# File C:\Appli\industrie4.0\conda\envs\ms\Lib\site-packages\LinearRegression\LinearRegression.py:166, in LinearRegression.fit(self, X, y_gt, y_intercept, standardize, regularization, penalty, penalty2)
#     164 while diff[-1] > self.eps:
#     165     if count%1000==0:
# --> 166         print(f'\n--- Itération {count} ---\nMSE = {self.J[-1]:.7E}')
#     167     count += 1
#     168     self.params = self._updateParams()
#
# TypeError: unsupported format string passed to NoneType.__format__
