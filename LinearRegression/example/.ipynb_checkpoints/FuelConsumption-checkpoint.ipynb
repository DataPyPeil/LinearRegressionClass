# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path
from LinearRegression import LinearRegression

# %% [markdown]
# ### Dataset Exploration

# %%
data_path = Path.cwd()
df_all = pd.read_csv(data_path / 'Life Expectancy Data.csv')
print(df_all.columns)
df_all.head(10)
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
# 5  Afghanistan  2010  Developing              58.8            279.0
# 6  Afghanistan  2009  Developing              58.6            281.0
# 7  Afghanistan  2008  Developing              58.1            287.0
# 8  Afghanistan  2007  Developing              57.5            295.0
# 9  Afghanistan  2006  Developing              57.3            295.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
# 5             74     0.01               79.679367         66.0      1989  ...
# 6             77     0.01               56.762217         63.0      2861  ...
# 7             80     0.03               25.873925         64.0      1599  ...
# 8             82     0.02               10.910156         63.0      1141  ...
# 9             84     0.03               17.171518         64.0      1990  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
# 5   66.0               9.20         66.0        0.1  553.328940   2883167.0
# 6   63.0               9.42         63.0        0.1  445.893298    284331.0
# 7   64.0               8.33         64.0        0.1  373.361116   2729431.0
# 8   63.0               6.73         63.0        0.1  369.835796  26616792.0
# 9   58.0               7.43         58.0        0.1  272.563770   2589345.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
# 5                   18.4                 18.4
# 6                   18.6                 18.7
# 7                   18.8                 18.9
# 8                   19.0                 19.1
# 9                   19.2                 19.3
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
# 5                            0.448        9.2
# 6                            0.434        8.9
# 7                            0.433        8.7
# 8                            0.415        8.4
# 9                            0.405        8.1
#
# [10 rows x 22 columns]

# %%
df = df_all[df_all['Status']=='Developing'].copy()
df.drop(['Year','Status'], axis=1, inplace=True)

# %%
df = df.groupby(by='Country').mean()
df
# Out:
#                                     Life expectancy   Adult Mortality  \
# Country
# Afghanistan                                 58.19375         269.0625
# Albania                                     75.15625          45.0625
# Algeria                                     73.61875         108.1875
# Angola                                      49.01875         328.5625
# Antigua and Barbuda                         75.05625         127.5000
# ...                                              ...              ...
# Venezuela (Bolivarian Republic of)          73.38750         163.0000
# Viet Nam                                    74.77500         126.5625
# Yemen                                       63.86250         211.8125
# Zambia                                      53.90625         354.3125
# Zimbabwe                                    50.48750         462.3750
#
#                                     infant deaths   Alcohol  \
# Country
# Afghanistan                               78.2500  0.014375
# Albania                                    0.6875  4.848750
# Algeria                                   20.3125  0.406667
# Angola                                    83.7500  5.740667
# Antigua and Barbuda                        0.0000  7.949333
# ...                                           ...       ...
# Venezuela (Bolivarian Republic of)         9.3750  7.420000
# Viet Nam                                  29.1875  3.087333
# Yemen                                     39.3750  0.047333
# Zambia                                    33.4375  2.239333
# Zimbabwe                                  26.5625  4.482000
#
#                                     percentage expenditure  Hepatitis B  \
# Country
# Afghanistan                                      34.960110    64.562500
# Albania                                         193.259091    98.000000
# Algeria                                         236.185241    78.000000
# Angola                                          102.100268    70.222222
# Antigua and Barbuda                            1001.585226    98.266667
# ...                                                    ...          ...
# Venezuela (Bolivarian Republic of)                0.000000    66.250000
# Viet Nam                                          0.000000    87.538462
# Yemen                                             0.000000    55.687500
# Zambia                                           89.650407    69.818182
# Zimbabwe                                         20.364271    70.562500
#
#                                      Measles       BMI   under-five deaths   \
# Country
# Afghanistan                         2362.2500  15.51875            107.5625
# Albania                               53.3750  49.06875              0.9375
# Algeria                             1943.8750  48.74375             23.5000
# Angola                              3561.3125  18.01875            132.6250
# Antigua and Barbuda                    0.0000  38.42500              0.0000
# ...                                       ...       ...                 ...
# Venezuela (Bolivarian Republic of)   165.0000  54.48750             10.7500
# Viet Nam                            4232.9375  11.18750             36.5000
# Yemen                               2761.1875  33.48750             51.6250
# Zambia                              6563.8125  17.45000             52.3750
# Zimbabwe                             923.0000  25.13750             40.8125
#
#                                       Polio  Total expenditure  Diphtheria   \
# Country
# Afghanistan                         48.3750           8.252500      52.3125
# Albania                             98.1250           5.945625      98.0625
# Algeria                             91.7500           4.604000      91.8750
# Angola                              46.1250           3.919333      47.6875
# Antigua and Barbuda                 96.9375           4.791333      98.3125
# ...                                     ...                ...          ...
# Venezuela (Bolivarian Republic of)  74.6875           4.998667      68.5000
# Viet Nam                            94.9375           5.977333      91.7500
# Yemen                               67.1250           5.005333      72.6250
# Zambia                              64.3750           5.824000      74.2500
# Zimbabwe                            75.6250           6.158667      75.1875
#
#                                      HIV/AIDS          GDP    Population  \
# Country
# Afghanistan                           0.10000   340.015425  9.972260e+06
# Albania                               0.10000  2119.726679  6.969116e+05
# Algeria                               0.10000  2847.853392  2.164983e+07
# Angola                                2.36875  1975.143045  1.014710e+07
# Antigua and Barbuda                   0.12500  9759.305728           NaN
# ...                                       ...          ...           ...
# Venezuela (Bolivarian Republic of)    0.10000          NaN           NaN
# Viet Nam                              0.14375          NaN           NaN
# Yemen                                 0.10000          NaN           NaN
# Zambia                               11.93125   811.811841  6.260246e+06
# Zimbabwe                             23.26250   410.980194  8.021343e+06
#
#                                      thinness  1-19 years  \
# Country
# Afghanistan                                      16.58125
# Albania                                           1.61875
# Algeria                                           6.09375
# Angola                                            6.19375
# Antigua and Barbuda                               3.42500
# ...                                                   ...
# Venezuela (Bolivarian Republic of)                1.65000
# Viet Nam                                         14.92500
# Yemen                                            13.83125
# Zambia                                            6.88125
# Zimbabwe                                          7.01250
#
#                                      thinness 5-9 years  \
# Country
# Afghanistan                                    15.58125
# Albania                                         1.70000
# Algeria                                         5.97500
# Angola                                          6.66875
# Antigua and Barbuda                             3.37500
# ...                                                 ...
# Venezuela (Bolivarian Republic of)              1.56250
# Viet Nam                                       15.62500
# Yemen                                          13.75000
# Zambia                                          6.76250
# Zimbabwe                                        6.98750
#
#                                     Income composition of resources  Schooling
# Country
# Afghanistan                                                0.415375    8.21250
# Albania                                                    0.709875   12.13750
# Algeria                                                    0.694875   12.71250
# Angola                                                     0.458375    8.04375
# Antigua and Barbuda                                        0.488625    8.84375
# ...                                                             ...        ...
# Venezuela (Bolivarian Republic of)                         0.726812   12.78750
# Viet Nam                                                   0.627062   11.51250
# Yemen                                                      0.475500    8.50625
# Zambia                                                     0.498437   11.21250
# Zimbabwe                                                   0.439125    9.82500
#
# [161 rows x 19 columns]

# %%
cols = ['Adult Mortality','infant deaths', 'GDP','Population','Life expectancy ']
df1 = df[cols]
df1
# Out:
#                                     Adult Mortality  infant deaths  \
# Country
# Afghanistan                                269.0625        78.2500
# Albania                                     45.0625         0.6875
# Algeria                                    108.1875        20.3125
# Angola                                     328.5625        83.7500
# Antigua and Barbuda                        127.5000         0.0000
# ...                                             ...            ...
# Venezuela (Bolivarian Republic of)         163.0000         9.3750
# Viet Nam                                   126.5625        29.1875
# Yemen                                      211.8125        39.3750
# Zambia                                     354.3125        33.4375
# Zimbabwe                                   462.3750        26.5625
#
#                                             GDP    Population  \
# Country
# Afghanistan                          340.015425  9.972260e+06
# Albania                             2119.726679  6.969116e+05
# Algeria                             2847.853392  2.164983e+07
# Angola                              1975.143045  1.014710e+07
# Antigua and Barbuda                 9759.305728           NaN
# ...                                         ...           ...
# Venezuela (Bolivarian Republic of)          NaN           NaN
# Viet Nam                                    NaN           NaN
# Yemen                                       NaN           NaN
# Zambia                               811.811841  6.260246e+06
# Zimbabwe                             410.980194  8.021343e+06
#
#                                     Life expectancy
# Country
# Afghanistan                                 58.19375
# Albania                                     75.15625
# Algeria                                     73.61875
# Angola                                      49.01875
# Antigua and Barbuda                         75.05625
# ...                                              ...
# Venezuela (Bolivarian Republic of)          73.38750
# Viet Nam                                    74.77500
# Yemen                                       63.86250
# Zambia                                      53.90625
# Zimbabwe                                    50.48750
#
# [161 rows x 5 columns]

# %%
df1.describe()
# Out:
#        Adult Mortality  infant deaths           GDP    Population  \
# count       151.000000     161.000000    135.000000  1.190000e+02
# mean        182.833195      34.265528   4147.613805  1.382418e+07
# std          95.659171     123.193058   6543.983041  4.180748e+07
# min          18.750000       0.000000    136.183210  2.920000e+02
# 25%         119.250000       0.500000    658.601705  8.477402e+05
# 50%         160.375000       4.000000   2000.245518  3.722046e+06
# 75%         232.250000      26.562500   4548.223703  1.130239e+07
# max         550.062500    1366.687500  40748.444104  4.214677e+08
#
#        Life expectancy
# count        151.000000
# mean          67.111465
# std            8.633224
# min           46.112500
# 25%           60.543750
# 50%           69.300000
# 75%           73.709375
# max           82.218750

# %%
sns.pairplot(df1)

# %%
numeric_df = df1.select_dtypes(include=[np.number])
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df1 = pd.DataFrame(scaler.fit_transform(df1), columns=cols)
sns.boxplot(df1)
# Out:
# <Axes: >

# %% [markdown]
# ### Dataset cleaning

# %%
# Remove Building Type
df=df1.copy()
# # cols_to_keep = ['Age','AnnualIncome','DebtToIncomeRatio','NetWorth','InterestRate','RiskScore']
# cols_to_keep = ['AnnualIncome','RiskScore']
# for x in df.columns:
#     if x not in cols_to_keep:
#         df = df.drop([x], axis=1)
# df

# %%
# Choose features to predict
feature_names = df.columns[:-1]
X, y = df[feature_names].to_numpy(), df[df.columns[-1]].to_numpy().reshape(-1,1)
print(f'Features: {feature_names} -- Shape: {X.shape}\nTarget: {df.columns[-1]} -- Shape: {y.shape}')
print(f'\n{df.dtypes}')
# Out:
# Features: Index(['Adult Mortality', 'infant deaths', 'GDP', 'Population'], dtype='object') -- Shape: (161, 4)
# Target: Life expectancy  -- Shape: (161, 1)
#
# Adult Mortality     float64
# infant deaths       float64
# GDP                 float64
# Population          float64
# Life expectancy     float64
# dtype: object

# %% [markdown]
# ### Linear Regression

# %%
model = LinearRegression(lr=1e-3, eps=1e-5)
model.fit(X, y)
y_pred = model.predict(X)
print(f'Classic LinearRegression: R²={model.score(y, y_pred):.4f}')
print(f'\nModel coefficients:\n{model.best_params}')

plt.figure(figsize=(18,5))
plt.suptitle('----- Training summary -----', fontsize=20)
plt.subplot(1,3,1)
model.plot_actualVSpredicted(y, y_pred)
plt.subplot(1,3,2)
model.plot()
plt.subplot(1,3,3)
model.featureimportance(names=feature_names)
plt.tight_layout()
plt.show()
# Out:
# Itération 000000: MSE=NAN
#
# Fit process ended with success after 1 iterations
# MSE = nan
#
# Classic LinearRegression: R²=nan
#
# Model coefficients:
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 10
#       8 plt.suptitle('----- Training summary -----', fontsize=20)
#       9 plt.subplot(1,3,1)
# ---> 10 model.plot_actualVSpredicted(y, y_pred)
#      11 plt.subplot(1,3,2)
#      12 model.plot()
#
# File C:\Appli\industrie4.0\conda\envs\ms\Lib\site-packages\LinearRegression\LinearRegression.py:304, in LinearRegression.plot_actualVSpredicted(self, y_gt, y_pred)
#     302 plt.plot(x, y, lw=1, ls='-', color='darkorange', label='y=x')
#     303 plt.fill_between(x, y_min, y_max, color="darkorange", alpha=0.2, label="Bande d'erreur (±5%)")
# --> 304 plt.xlim(np.min(y_gt)*0.8, np.max(y_gt)*1.2)
#     305 plt.ylim(np.min(y_pred)*0.8, np.max(y_pred)*1.2)
#     306 plt.xlabel('Actual')
#
# File C:\Appli\industrie4.0\conda\envs\ms\Lib\site-packages\matplotlib\pyplot.py:2107, in xlim(*args, **kwargs)
#    2105 if not args and not kwargs:
#    2106     return ax.get_xlim()
# -> 2107 ret = ax.set_xlim(*args, **kwargs)
#    2108 return ret
#
# File C:\Appli\industrie4.0\conda\envs\ms\Lib\site-packages\matplotlib\axes\_base.py:3739, in _AxesBase.set_xlim(self, left, right, emit, auto, xmin, xmax)
#    3737         raise TypeError("Cannot pass both 'right' and 'xmax'")
#    3738     right = xmax
# -> 3739 return self.xaxis._set_lim(left, right, emit=emit, auto=auto)
#
# File C:\Appli\industrie4.0\conda\envs\ms\Lib\site-packages\matplotlib\axis.py:1236, in Axis._set_lim(self, v0, v1, emit, auto)
#    1233 name = self._get_axis_name()
#    1235 self.axes._process_unit_info([(name, (v0, v1))], convert=False)
# -> 1236 v0 = self.axes._validate_converted_limits(v0, self.convert_units)
#    1237 v1 = self.axes._validate_converted_limits(v1, self.convert_units)
#    1239 if v0 is None or v1 is None:
#    1240     # Axes init calls set_xlim(0, 1) before get_xlim() can be called,
#    1241     # so only grab the limits if we really need them.
#
# File C:\Appli\industrie4.0\conda\envs\ms\Lib\site-packages\matplotlib\axes\_base.py:3660, in _AxesBase._validate_converted_limits(self, limit, convert)
#    3657     converted_limit = converted_limit.squeeze()
#    3658 if (isinstance(converted_limit, Real)
#    3659         and not np.isfinite(converted_limit)):
# -> 3660     raise ValueError("Axis limits cannot be NaN or Inf")
#    3661 return converted_limit
#
# ValueError: Axis limits cannot be NaN or Inf

# %% [markdown]
# ### Linear Regression + STANDARDISATION

# %%
model = LinearRegression(lr=1e-3, eps=1e-7)
model.fit(X, y, standardize=True)
y_pred = model.predict(X)
print(f'LinearRegression + Standardisation: R²={model.score(y, y_pred):.4f}')
print(f'\nModel coefficients:\n{model.best_params}')

plt.figure(figsize=(18,5))
plt.suptitle('----- Training summary -----', fontsize=20)
plt.subplot(1,3,1)
model.plot_actualVSpredicted(y, y_pred)
plt.subplot(1,3,2)
model.plot()
plt.subplot(1,3,3)
model.featureimportance(names=feature_names)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Linear Regression + REGULARIZATION

# %%
model = LinearRegression(lr=1e-3, eps=1e-7)
model.fit(X, y, regularization='LASSO', penalty=5)
y_pred = model.predict(X)
print(f'LinearRegression + Regularization: R²={model.score(y, y_pred):.4f}')
print(f'\nModel coefficients:\n{model.best_params}')

plt.figure(figsize=(18,5))
plt.suptitle('----- Training summary -----', fontsize=20)
plt.subplot(1,3,1)
model.plot_actualVSpredicted(y, y_pred)
plt.subplot(1,3,2)
model.plot()
plt.subplot(1,3,3)
model.featureimportance(names=feature_names)
plt.tight_layout()
plt.show()

# %% [markdown]
# # OTHERS

# %%
def plot_mse(y_pred, y_gt, threshold=0):
    error = np.abs(y_pred-y_gt)

    plt.figure(figsize=(30,10))
    plt.stem(error, linefmt='navy')
    plt.hlines(threshold, 0, y_pred.shape[0], lw=2, ls=':', color='darkorange')
    plt.ylabel('|y_pred-y_gt|')
    plt.show()
plot_mse(y_pred, y)

# %%
from sklearn.linear_model import SGDRegressor
sgd = SGDRegressor(max_iter=10000, learning_rate='constant', eta0=1e-12, random_state=42)
sgd.fit(X, y)
sgd.score(X, y)
# sgd.coef_
